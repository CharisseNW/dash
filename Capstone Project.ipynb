# %% [markdown]
# # *Applied Data Science Capstone*
# ## Assignment 1
# ### Week 1

# %% [markdown]
# This **notebook** will be mainly used for the Applied Data Science *Capstone* project, because:
# 1. It is a requirement of Course 9
# 2. It is the final requirement to earn the DSP certificate
# 3. It facilitates knowledge integration
# 4. It confirms the student's understanding of the previous 8 modules

# %%
import pandas as pd

# %%
import numpy as np

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
